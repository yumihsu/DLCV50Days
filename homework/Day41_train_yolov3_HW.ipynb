# %% [markdown]
# ## 作業
#
# 1. 如何使用已經訓練好的模型？

# %%
# %tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %% [markdown]
# pip install keras==2.2.4 # 需要安裝 keras 2.2.4 的版本

# %% [markdown]
# from google.colab import drive
# drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# #### 下載基於 keras 的 yolov3 程式碼
# %cd 'gdrive/My Drive'
# #### !git clone https://github.com/qqwweee/keras-yolo3 # 如果之前已經下載過就可以註解掉
# %cd keras-yolo3

# %%
from PIL import Image
image = Image.open('dog.jpg') 
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x576 at 0x1599AA27A90>

# %%
from yolo import YOLO

# %%
classes_path = 'model_data/voc_classes.txt'
model_path = 'model_data/yolo.h5'
yolo_model = YOLO(model_path = model_path )
# Out:
# model_data/yolo.h5 model, anchors, and classes loaded.

# %%
resultimage , detect , score , classes = yolo_model.detect_image(image)
# Out:
# (416, 416, 3)
# Found 3 boxes for img
# dog 0.99 (128, 224) (314, 537)
# truck 0.91 (475, 85) (688, 170)
# bicycle 0.99 (162, 118) (565, 442)
# 2.870565099999965

# %%
resultimage
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x576 at 0x1599AA27A90>

# %%
 detect , score , classes
# Out:
# (array([[118.33539 , 162.1088  , 441.5663  , 564.8148  ],
#         [ 85.467094, 474.9532  , 169.98491 , 688.4038  ],
#         [224.21854 , 127.9583  , 537.04596 , 313.94232 ]], dtype=float32),
#  array([0.993366  , 0.91374946, 0.98901445], dtype=float32),
#  array([ 1,  7, 16]))

# %% [raw]
# # 2. 依照 https://github.com/qqwweee/keras-yolo3 的程式碼，請敘述，訓練模型時，資料集的格式是什麼？具體一點的說，要提供什麼格式的文件來描述資料集的圖片以及 bboxes 的信息呢？
# center_x:物件的x在這張圖片中的水平比例位置
# center_y:物件的y在這張圖片中的垂直比例位置
# width:物件的寬度在圖片中的比例
# height:物件的高度在圖片中的比例
# classes_number:物件的編號代碼
# ans :
# [image_path , center_x, center_y, width , height , classes_number\n,   #\n分行便於閱讀
# image_path , center_x, center_y, width , height , classes_number..........]
# ex:
# ['./JPEGImages/000012.jpg 156,97,351,270,6\n',
#  './JPEGImages/000017.jpg 185,62,279,199,14 90,78,403,336,12\n',
#  './JPEGImages/000023.jpg 9,230,245,500,1 230,220,334,500,1 2,1,117,369,14 3,2,243,462,14 225,1,334,486,14\n', #如果同一張圖有多個label，就持續把x,y,w,h,c寫完
