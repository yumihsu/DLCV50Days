# %% [markdown]
# ### 作業
# 請嘗試使用 flip (左右翻轉) 來做 augmentation 以降低人臉關鍵點檢測的 loss
#
# Note: 圖像 flip 之後，groundtruth 的關鍵點也要跟著 flip 哦

# %% [markdown]
# ### 範例
# 接下來的程式碼會示範如何定義一個簡單的 CNN model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#使用 colab 環境的同學請執行以下程式碼
#%tensorflow_version 1.x # 確保 colob 中使用的 tensorflow 是 1.x 版本而不是 tensorflow 2
import tensorflow as tf
print(tf.__version__)
import os
from google.colab import drive 
drive.mount('/content/gdrive') # 將 google drive 掛載在 colob，
# %cd 'gdrive/My Drive'
# Out:
# 2.5.0
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/My Drive'
# /content/gdrive/My Drive

# %%
# 讀取資料集以及做前處理的函數
def load_data(dirname):
    # 讀取 csv 文件
    data = pd.read_csv(dirname)
    # 過濾有缺失值的 row
    data = data.dropna()

    # 將圖片像素值讀取為 numpy array 的形態
    data['Image'] = data['Image'].apply(lambda img: np.fromstring(img, sep=' ')).values 

    # 單獨把圖像 array 抽取出來
    imgs = np.vstack(data['Image'].values)/255
    # reshape 為 96 x 96
    imgs = imgs.reshape(data.shape[0], 96, 96)
    # 轉換為 float
    imgs = imgs.astype(np.float32)
    
    # 提取坐標的部分
    points = data[data.columns[:-1]].values

    # 轉換為 float
    points = points.astype(np.float32)

    # normalize 坐標值到 [-0.5, 0.5]
    points = points/96 - 0.5
    
    return imgs, points

# %%
# 讀取資料
imgs_train, points_train = load_data(dirname = 'training.csv')
print("圖像資料:", imgs_train.shape, "\n關鍵點資料:", points_train.shape)
# Out:
# 圖像資料: (2140, 96, 96)
# 關鍵點資料: (2140, 30)

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
# 回傳定義好的 model 的函數
def get_model():
    # 定義人臉關鍵點檢測網路
    model = Sequential()

    # 定義神經網路的輸入
    model.add(Conv2D(filters=16, kernel_size=3, activation='relu', input_shape=(96, 96, 1)))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=32, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=64, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Conv2D(filters=128, kernel_size=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=2))

    model.add(Flatten())
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.2))

    # 最後輸出 30 維的向量，也就是 15 個關鍵點的值
    model.add(Dense(30))
    return model

# %%
model = get_model()
# 配置 loss funtion 和 optimizer
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
from keras.callbacks import ModelCheckpoint, History
# model checkpoint 
checkpoint = ModelCheckpoint('best_weights.h5', verbose=1, save_best_only=True)
hist = History()

# %%
# training the model
hist_model = model.fit(imgs_train.reshape(-1, 96, 96, 1), 
                       points_train, 
                       validation_split=0.2, batch_size=64, callbacks=[checkpoint, hist],
                       shuffle=True, epochs=150, verbose=1)
# save the model weights
model.save_weights('weights.h5')
# save the model
model.save('model.h5')
# Out:
# Epoch 1/150
# 27/27 [==============================] - 31s 527ms/step - loss: 0.0182 - val_loss: 0.0024
#
# Epoch 00001: val_loss improved from inf to 0.00240, saving model to best_weights.h5
# Epoch 2/150
# 27/27 [==============================] - 14s 503ms/step - loss: 0.0030 - val_loss: 0.0019
#
# Epoch 00002: val_loss improved from 0.00240 to 0.00192, saving model to best_weights.h5
# Epoch 3/150
# 27/27 [==============================] - 14s 503ms/step - loss: 0.0022 - val_loss: 0.0020
#
# Epoch 00003: val_loss did not improve from 0.00192
# Epoch 4/150
# 27/27 [==============================] - 14s 501ms/step - loss: 0.0018 - val_loss: 0.0019
#
# Epoch 00004: val_loss improved from 0.00192 to 0.00186, saving model to best_weights.h5
# Epoch 5/150
# 27/27 [==============================] - 14s 501ms/step - loss: 0.0016 - val_loss: 0.0020
#
# Epoch 00005: val_loss did not improve from 0.00186
# Epoch 6/150
# 27/27 [==============================] - 14s 501ms/step - loss: 0.0015 - val_loss: 0.0019
#
# Epoch 00006: val_loss did not improve from 0.00186
# Epoch 7/150
# 27/27 [==============================] - 13s 500ms/step - loss: 0.0013 - val_loss: 0.0019
#
# Epoch 00007: val_loss did not improve from 0.00186
# Epoch 8/150
# 27/27 [==============================] - 13s 501ms/step - loss: 0.0012 - val_loss: 0.0018
#
# Epoch 00008: val_loss improved from 0.00186 to 0.00181, saving model to best_weights.h5
# Epoch 9/150
# 27/27 [==============================] - 14s 506ms/step - loss: 0.0011 - val_loss: 0.0018
#
# Epoch 00009: val_loss improved from 0.00181 to 0.00176, saving model to best_weights.h5
# Epoch 10/150
# 27/27 [==============================] - 14s 506ms/step - loss: 9.8636e-04 - val_loss: 0.0016
#
# Epoch 00010: val_loss improved from 0.00176 to 0.00165, saving model to best_weights.h5
# Epoch 11/150
# 27/27 [==============================] - 14s 506ms/step - loss: 9.1270e-04 - val_loss: 0.0016
#
# Epoch 00011: val_loss improved from 0.00165 to 0.00161, saving model to best_weights.h5
# Epoch 12/150
# 27/27 [==============================] - 14s 507ms/step - loss: 8.3041e-04 - val_loss: 0.0014
#
# Epoch 00012: val_loss improved from 0.00161 to 0.00141, saving model to best_weights.h5
# Epoch 13/150
# 27/27 [==============================] - 14s 507ms/step - loss: 7.6465e-04 - val_loss: 0.0013
#
# Epoch 00013: val_loss improved from 0.00141 to 0.00132, saving model to best_weights.h5
# Epoch 14/150
# 27/27 [==============================] - 14s 504ms/step - loss: 7.4044e-04 - val_loss: 0.0012
#
# Epoch 00014: val_loss improved from 0.00132 to 0.00125, saving model to best_weights.h5
# Epoch 15/150
# 27/27 [==============================] - 14s 510ms/step - loss: 6.6661e-04 - val_loss: 0.0012
#
# Epoch 00015: val_loss improved from 0.00125 to 0.00119, saving model to best_weights.h5
# Epoch 16/150
# 27/27 [==============================] - 14s 508ms/step - loss: 6.6632e-04 - val_loss: 0.0012
#
# Epoch 00016: val_loss improved from 0.00119 to 0.00118, saving model to best_weights.h5
# Epoch 17/150
# 27/27 [==============================] - 14s 508ms/step - loss: 6.2011e-04 - val_loss: 0.0011
#
# Epoch 00017: val_loss improved from 0.00118 to 0.00109, saving model to best_weights.h5
# Epoch 18/150
# 27/27 [==============================] - 14s 505ms/step - loss: 5.9427e-04 - val_loss: 0.0011
#
# Epoch 00018: val_loss did not improve from 0.00109
# Epoch 19/150
# 27/27 [==============================] - 14s 507ms/step - loss: 5.5174e-04 - val_loss: 0.0011
#
# Epoch 00019: val_loss did not improve from 0.00109
# Epoch 20/150
# 27/27 [==============================] - 14s 504ms/step - loss: 5.6387e-04 - val_loss: 0.0011
#
# Epoch 00020: val_loss improved from 0.00109 to 0.00107, saving model to best_weights.h5
# Epoch 21/150
# 27/27 [==============================] - 14s 507ms/step - loss: 5.3862e-04 - val_loss: 0.0010
#
# Epoch 00021: val_loss improved from 0.00107 to 0.00101, saving model to best_weights.h5
# Epoch 22/150
# 27/27 [==============================] - 14s 508ms/step - loss: 5.2176e-04 - val_loss: 9.9209e-04
#
# Epoch 00022: val_loss improved from 0.00101 to 0.00099, saving model to best_weights.h5
# Epoch 23/150
# 27/27 [==============================] - 14s 506ms/step - loss: 5.0718e-04 - val_loss: 0.0010
#
# Epoch 00023: val_loss did not improve from 0.00099
# Epoch 24/150
# 27/27 [==============================] - 14s 504ms/step - loss: 4.8626e-04 - val_loss: 9.9156e-04
#
# Epoch 00024: val_loss improved from 0.00099 to 0.00099, saving model to best_weights.h5
# Epoch 25/150
# 27/27 [==============================] - 14s 502ms/step - loss: 4.6092e-04 - val_loss: 9.5405e-04
#
# Epoch 00025: val_loss improved from 0.00099 to 0.00095, saving model to best_weights.h5
# Epoch 26/150
# 27/27 [==============================] - 14s 506ms/step - loss: 4.5446e-04 - val_loss: 9.4519e-04
#
# Epoch 00026: val_loss improved from 0.00095 to 0.00095, saving model to best_weights.h5
# Epoch 27/150
# 27/27 [==============================] - 14s 503ms/step - loss: 4.4906e-04 - val_loss: 9.4080e-04
#
# Epoch 00027: val_loss improved from 0.00095 to 0.00094, saving model to best_weights.h5
# Epoch 28/150
# 27/27 [==============================] - 14s 503ms/step - loss: 4.3407e-04 - val_loss: 9.8692e-04
#
# Epoch 00028: val_loss did not improve from 0.00094
# Epoch 29/150
# 27/27 [==============================] - 14s 503ms/step - loss: 4.2877e-04 - val_loss: 9.3533e-04
#
# Epoch 00029: val_loss improved from 0.00094 to 0.00094, saving model to best_weights.h5
# Epoch 30/150
# 27/27 [==============================] - 14s 508ms/step - loss: 4.0906e-04 - val_loss: 9.6570e-04
#
# Epoch 00030: val_loss did not improve from 0.00094
# Epoch 31/150
# 27/27 [==============================] - 14s 502ms/step - loss: 3.9787e-04 - val_loss: 9.4469e-04
#
# Epoch 00031: val_loss did not improve from 0.00094
# Epoch 32/150
# 27/27 [==============================] - 14s 502ms/step - loss: 3.8791e-04 - val_loss: 9.3747e-04
#
# Epoch 00032: val_loss did not improve from 0.00094
# Epoch 33/150
# 27/27 [==============================] - 14s 503ms/step - loss: 3.7729e-04 - val_loss: 8.8485e-04
#
# Epoch 00033: val_loss improved from 0.00094 to 0.00088, saving model to best_weights.h5
# Epoch 34/150
# 27/27 [==============================] - 14s 503ms/step - loss: 3.7238e-04 - val_loss: 9.5402e-04
#
# Epoch 00034: val_loss did not improve from 0.00088
# Epoch 35/150
# 27/27 [==============================] - 14s 502ms/step - loss: 3.6801e-04 - val_loss: 8.9637e-04
#
# Epoch 00035: val_loss did not improve from 0.00088
# Epoch 36/150
# 27/27 [==============================] - 13s 500ms/step - loss: 3.6119e-04 - val_loss: 9.5227e-04
#
# Epoch 00036: val_loss did not improve from 0.00088
# Epoch 37/150
# 27/27 [==============================] - 14s 503ms/step - loss: 3.5616e-04 - val_loss: 9.0550e-04
#
# Epoch 00037: val_loss did not improve from 0.00088
# Epoch 38/150
# 27/27 [==============================] - 14s 502ms/step - loss: 3.5441e-04 - val_loss: 9.0346e-04
#
# Epoch 00038: val_loss did not improve from 0.00088
# Epoch 39/150
# 27/27 [==============================] - 14s 503ms/step - loss: 3.4831e-04 - val_loss: 9.1875e-04
#
# Epoch 00039: val_loss did not improve from 0.00088
# Epoch 40/150
# 27/27 [==============================] - 14s 502ms/step - loss: 3.2636e-04 - val_loss: 8.7892e-04
#
# Epoch 00040: val_loss improved from 0.00088 to 0.00088, saving model to best_weights.h5
# Epoch 41/150
# 27/27 [==============================] - 14s 505ms/step - loss: 3.2460e-04 - val_loss: 8.8666e-04
#
# Epoch 00041: val_loss did not improve from 0.00088
# Epoch 42/150
# 27/27 [==============================] - 14s 504ms/step - loss: 3.1891e-04 - val_loss: 8.9591e-04
#
# Epoch 00042: val_loss did not improve from 0.00088
# Epoch 43/150
# 27/27 [==============================] - 14s 503ms/step - loss: 3.1640e-04 - val_loss: 8.8315e-04
#
# Epoch 00043: val_loss did not improve from 0.00088
# Epoch 44/150
# 27/27 [==============================] - 14s 504ms/step - loss: 3.1225e-04 - val_loss: 8.5877e-04
#
# Epoch 00044: val_loss improved from 0.00088 to 0.00086, saving model to best_weights.h5
# Epoch 45/150
# 27/27 [==============================] - 14s 501ms/step - loss: 3.0107e-04 - val_loss: 8.7088e-04
#
# Epoch 00045: val_loss did not improve from 0.00086
# Epoch 46/150
# 27/27 [==============================] - 14s 503ms/step - loss: 2.9370e-04 - val_loss: 9.0215e-04
#
# Epoch 00046: val_loss did not improve from 0.00086
# Epoch 47/150
# 27/27 [==============================] - 14s 502ms/step - loss: 2.8921e-04 - val_loss: 8.5416e-04
#
# Epoch 00047: val_loss improved from 0.00086 to 0.00085, saving model to best_weights.h5
# Epoch 48/150
# 27/27 [==============================] - 14s 503ms/step - loss: 2.8822e-04 - val_loss: 8.6813e-04
#
# Epoch 00048: val_loss did not improve from 0.00085
# Epoch 49/150
# 27/27 [==============================] - 13s 500ms/step - loss: 2.7703e-04 - val_loss: 8.3277e-04
#
# Epoch 00049: val_loss improved from 0.00085 to 0.00083, saving model to best_weights.h5
# Epoch 50/150
# 27/27 [==============================] - 14s 503ms/step - loss: 2.7761e-04 - val_loss: 8.6173e-04
#
# Epoch 00050: val_loss did not improve from 0.00083
# Epoch 51/150
# 27/27 [==============================] - 13s 501ms/step - loss: 2.7470e-04 - val_loss: 9.0582e-04
#
# Epoch 00051: val_loss did not improve from 0.00083
# Epoch 52/150
# 27/27 [==============================] - 14s 504ms/step - loss: 2.7370e-04 - val_loss: 8.5599e-04
#
# Epoch 00052: val_loss did not improve from 0.00083
# Epoch 53/150
# 27/27 [==============================] - 14s 502ms/step - loss: 2.6279e-04 - val_loss: 8.6086e-04
#
# Epoch 00053: val_loss did not improve from 0.00083
# Epoch 54/150
# 27/27 [==============================] - 14s 501ms/step - loss: 2.5014e-04 - val_loss: 8.5986e-04
#
# Epoch 00054: val_loss did not improve from 0.00083
# Epoch 55/150
# 27/27 [==============================] - 13s 500ms/step - loss: 2.5179e-04 - val_loss: 8.8008e-04
#
# Epoch 00055: val_loss did not improve from 0.00083
# Epoch 56/150
# 27/27 [==============================] - 13s 500ms/step - loss: 2.5772e-04 - val_loss: 9.1938e-04
#
# Epoch 00056: val_loss did not improve from 0.00083
# Epoch 57/150
# 27/27 [==============================] - 14s 502ms/step - loss: 2.5645e-04 - val_loss: 8.7059e-04
#
# Epoch 00057: val_loss did not improve from 0.00083
# Epoch 58/150
# 27/27 [==============================] - 13s 499ms/step - loss: 2.5360e-04 - val_loss: 8.3715e-04
#
# Epoch 00058: val_loss did not improve from 0.00083
# Epoch 59/150
# 27/27 [==============================] - 13s 500ms/step - loss: 2.5544e-04 - val_loss: 8.6058e-04
#
# Epoch 00059: val_loss did not improve from 0.00083
# Epoch 60/150
# 27/27 [==============================] - 13s 499ms/step - loss: 2.3267e-04 - val_loss: 8.5427e-04
#
# Epoch 00060: val_loss did not improve from 0.00083
# Epoch 61/150
# 27/27 [==============================] - 14s 503ms/step - loss: 2.3552e-04 - val_loss: 8.4633e-04
#
# Epoch 00061: val_loss did not improve from 0.00083
# Epoch 62/150
# 27/27 [==============================] - 14s 502ms/step - loss: 2.3686e-04 - val_loss: 8.5782e-04
#
# Epoch 00062: val_loss did not improve from 0.00083
# Epoch 63/150
# 27/27 [==============================] - 14s 501ms/step - loss: 2.2866e-04 - val_loss: 8.5218e-04
#
# Epoch 00063: val_loss did not improve from 0.00083
# Epoch 64/150
# 27/27 [==============================] - 14s 505ms/step - loss: 2.3031e-04 - val_loss: 8.5436e-04
#
# Epoch 00064: val_loss did not improve from 0.00083
# Epoch 65/150
# 27/27 [==============================] - 14s 501ms/step - loss: 2.2360e-04 - val_loss: 8.9474e-04
#
# Epoch 00065: val_loss did not improve from 0.00083
# Epoch 66/150
# 27/27 [==============================] - 14s 505ms/step - loss: 2.2972e-04 - val_loss: 8.5520e-04
#
# Epoch 00066: val_loss did not improve from 0.00083
# Epoch 67/150
# 27/27 [==============================] - 14s 503ms/step - loss: 2.2482e-04 - val_loss: 8.6861e-04
#
# Epoch 00067: val_loss did not improve from 0.00083
# Epoch 68/150
# 27/27 [==============================] - 14s 502ms/step - loss: 2.2298e-04 - val_loss: 8.7043e-04
#
# Epoch 00068: val_loss did not improve from 0.00083
# Epoch 69/150
# 27/27 [==============================] - 14s 502ms/step - loss: 2.1037e-04 - val_loss: 8.6102e-04
#
# Epoch 00069: val_loss did not improve from 0.00083
# Epoch 70/150
# 27/27 [==============================] - 14s 504ms/step - loss: 2.2118e-04 - val_loss: 8.4856e-04
#
# Epoch 00070: val_loss did not improve from 0.00083
# Epoch 71/150
# 27/27 [==============================] - 14s 502ms/step - loss: 2.2389e-04 - val_loss: 8.3471e-04
#
# Epoch 00071: val_loss did not improve from 0.00083
# Epoch 72/150
# 27/27 [==============================] - 14s 501ms/step - loss: 2.1160e-04 - val_loss: 7.9498e-04
#
# Epoch 00072: val_loss improved from 0.00083 to 0.00079, saving model to best_weights.h5
# Epoch 73/150
# 27/27 [==============================] - 13s 501ms/step - loss: 2.0622e-04 - val_loss: 8.6082e-04
#
# Epoch 00073: val_loss did not improve from 0.00079
# Epoch 74/150
# 27/27 [==============================] - 13s 500ms/step - loss: 2.0309e-04 - val_loss: 8.0711e-04
#
# Epoch 00074: val_loss did not improve from 0.00079
# Epoch 75/150
# 27/27 [==============================] - 13s 499ms/step - loss: 2.1391e-04 - val_loss: 8.5990e-04
#
# Epoch 00075: val_loss did not improve from 0.00079
# Epoch 76/150
# 27/27 [==============================] - 13s 499ms/step - loss: 2.0674e-04 - val_loss: 8.3108e-04
#
# Epoch 00076: val_loss did not improve from 0.00079
# Epoch 77/150
# 27/27 [==============================] - 14s 507ms/step - loss: 1.9911e-04 - val_loss: 8.4067e-04
#
# Epoch 00077: val_loss did not improve from 0.00079
# Epoch 78/150
# 27/27 [==============================] - 13s 499ms/step - loss: 1.9800e-04 - val_loss: 8.3336e-04
#
# Epoch 00078: val_loss did not improve from 0.00079
# Epoch 79/150
# 27/27 [==============================] - 13s 500ms/step - loss: 1.9196e-04 - val_loss: 8.1235e-04
#
# Epoch 00079: val_loss did not improve from 0.00079
# Epoch 80/150
# 27/27 [==============================] - 14s 501ms/step - loss: 1.9436e-04 - val_loss: 8.2803e-04
#
# Epoch 00080: val_loss did not improve from 0.00079
# Epoch 81/150
# 27/27 [==============================] - 13s 500ms/step - loss: 1.9349e-04 - val_loss: 8.4503e-04
#
# Epoch 00081: val_loss did not improve from 0.00079
# Epoch 82/150
# 27/27 [==============================] - 14s 506ms/step - loss: 1.9301e-04 - val_loss: 8.3014e-04
#
# Epoch 00082: val_loss did not improve from 0.00079
# Epoch 83/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.8753e-04 - val_loss: 8.1949e-04
#
# Epoch 00083: val_loss did not improve from 0.00079
# Epoch 84/150
# 27/27 [==============================] - 14s 510ms/step - loss: 1.8858e-04 - val_loss: 8.3486e-04
#
# Epoch 00084: val_loss did not improve from 0.00079
# Epoch 85/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.8731e-04 - val_loss: 8.0726e-04
#
# Epoch 00085: val_loss did not improve from 0.00079
# Epoch 86/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.8711e-04 - val_loss: 7.9764e-04
#
# Epoch 00086: val_loss did not improve from 0.00079
# Epoch 87/150
# 27/27 [==============================] - 14s 502ms/step - loss: 1.9069e-04 - val_loss: 8.2549e-04
#
# Epoch 00087: val_loss did not improve from 0.00079
# Epoch 88/150
# 27/27 [==============================] - 14s 505ms/step - loss: 1.8193e-04 - val_loss: 8.1268e-04
#
# Epoch 00088: val_loss did not improve from 0.00079
# Epoch 89/150
# 27/27 [==============================] - 13s 500ms/step - loss: 1.7794e-04 - val_loss: 8.1555e-04
#
# Epoch 00089: val_loss did not improve from 0.00079
# Epoch 90/150
# 27/27 [==============================] - 13s 500ms/step - loss: 1.7978e-04 - val_loss: 7.9919e-04
#
# Epoch 00090: val_loss did not improve from 0.00079
# Epoch 91/150
# 27/27 [==============================] - 13s 499ms/step - loss: 1.7019e-04 - val_loss: 7.9328e-04
#
# Epoch 00091: val_loss improved from 0.00079 to 0.00079, saving model to best_weights.h5
# Epoch 92/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.8057e-04 - val_loss: 8.1042e-04
#
# Epoch 00092: val_loss did not improve from 0.00079
# Epoch 93/150
# 27/27 [==============================] - 14s 500ms/step - loss: 1.7139e-04 - val_loss: 8.1088e-04
#
# Epoch 00093: val_loss did not improve from 0.00079
# Epoch 94/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.7700e-04 - val_loss: 8.2227e-04
#
# Epoch 00094: val_loss did not improve from 0.00079
# Epoch 95/150
# 27/27 [==============================] - 14s 501ms/step - loss: 1.7753e-04 - val_loss: 8.5295e-04
#
# Epoch 00095: val_loss did not improve from 0.00079
# Epoch 96/150
# 27/27 [==============================] - 14s 501ms/step - loss: 1.7629e-04 - val_loss: 8.2423e-04
#
# Epoch 00096: val_loss did not improve from 0.00079
# Epoch 97/150
# 27/27 [==============================] - 14s 507ms/step - loss: 1.6684e-04 - val_loss: 8.2428e-04
#
# Epoch 00097: val_loss did not improve from 0.00079
# Epoch 98/150
# 27/27 [==============================] - 14s 502ms/step - loss: 1.7186e-04 - val_loss: 8.0887e-04
#
# Epoch 00098: val_loss did not improve from 0.00079
# Epoch 99/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.6728e-04 - val_loss: 8.1346e-04
#
# Epoch 00099: val_loss did not improve from 0.00079
# Epoch 100/150
# 27/27 [==============================] - 14s 505ms/step - loss: 1.6655e-04 - val_loss: 8.4561e-04
#
# Epoch 00100: val_loss did not improve from 0.00079
# Epoch 101/150
# 27/27 [==============================] - 14s 505ms/step - loss: 1.7011e-04 - val_loss: 7.9038e-04
#
# Epoch 00101: val_loss improved from 0.00079 to 0.00079, saving model to best_weights.h5
# Epoch 102/150
# 27/27 [==============================] - 14s 505ms/step - loss: 1.6716e-04 - val_loss: 8.2911e-04
#
# Epoch 00102: val_loss did not improve from 0.00079
# Epoch 103/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.6891e-04 - val_loss: 8.2967e-04
#
# Epoch 00103: val_loss did not improve from 0.00079
# Epoch 104/150
# 27/27 [==============================] - 14s 502ms/step - loss: 1.6634e-04 - val_loss: 8.1901e-04
#
# Epoch 00104: val_loss did not improve from 0.00079
# Epoch 105/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.6763e-04 - val_loss: 8.4602e-04
#
# Epoch 00105: val_loss did not improve from 0.00079
# Epoch 106/150
# 27/27 [==============================] - 14s 506ms/step - loss: 1.6726e-04 - val_loss: 8.1634e-04
#
# Epoch 00106: val_loss did not improve from 0.00079
# Epoch 107/150
# 27/27 [==============================] - 14s 506ms/step - loss: 1.6661e-04 - val_loss: 7.8700e-04
#
# Epoch 00107: val_loss improved from 0.00079 to 0.00079, saving model to best_weights.h5
# Epoch 108/150
# 27/27 [==============================] - 14s 513ms/step - loss: 1.6209e-04 - val_loss: 8.1727e-04
#
# Epoch 00108: val_loss did not improve from 0.00079
# Epoch 109/150
# 27/27 [==============================] - 14s 507ms/step - loss: 1.5817e-04 - val_loss: 7.9782e-04
#
# Epoch 00109: val_loss did not improve from 0.00079
# Epoch 110/150
# 27/27 [==============================] - 14s 505ms/step - loss: 1.5410e-04 - val_loss: 8.1118e-04
#
# Epoch 00110: val_loss did not improve from 0.00079
# Epoch 111/150
# 27/27 [==============================] - 14s 505ms/step - loss: 1.5449e-04 - val_loss: 8.2666e-04
#
# Epoch 00111: val_loss did not improve from 0.00079
# Epoch 112/150
# 27/27 [==============================] - 14s 507ms/step - loss: 1.5779e-04 - val_loss: 7.8861e-04
#
# Epoch 00112: val_loss did not improve from 0.00079
# Epoch 113/150
# 27/27 [==============================] - 14s 508ms/step - loss: 1.6066e-04 - val_loss: 8.0429e-04
#
# Epoch 00113: val_loss did not improve from 0.00079
# Epoch 114/150
# 27/27 [==============================] - 14s 505ms/step - loss: 1.6186e-04 - val_loss: 7.9877e-04
#
# Epoch 00114: val_loss did not improve from 0.00079
# Epoch 115/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.5679e-04 - val_loss: 8.0961e-04
#
# Epoch 00115: val_loss did not improve from 0.00079
# Epoch 116/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.5548e-04 - val_loss: 8.0363e-04
#
# Epoch 00116: val_loss did not improve from 0.00079
# Epoch 117/150
# 27/27 [==============================] - 14s 506ms/step - loss: 1.5678e-04 - val_loss: 7.9583e-04
#
# Epoch 00117: val_loss did not improve from 0.00079
# Epoch 118/150
# 27/27 [==============================] - 14s 502ms/step - loss: 1.5684e-04 - val_loss: 7.9659e-04
#
# Epoch 00118: val_loss did not improve from 0.00079
# Epoch 119/150
# 27/27 [==============================] - 14s 505ms/step - loss: 1.5329e-04 - val_loss: 8.2088e-04
#
# Epoch 00119: val_loss did not improve from 0.00079
# Epoch 120/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.4505e-04 - val_loss: 7.9695e-04
#
# Epoch 00120: val_loss did not improve from 0.00079
# Epoch 121/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.5049e-04 - val_loss: 8.2341e-04
#
# Epoch 00121: val_loss did not improve from 0.00079
# Epoch 122/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.4851e-04 - val_loss: 7.9318e-04
#
# Epoch 00122: val_loss did not improve from 0.00079
# Epoch 123/150
# 27/27 [==============================] - 14s 502ms/step - loss: 1.4773e-04 - val_loss: 8.0282e-04
#
# Epoch 00123: val_loss did not improve from 0.00079
# Epoch 124/150
# 27/27 [==============================] - 14s 502ms/step - loss: 1.4895e-04 - val_loss: 7.8839e-04
#
# Epoch 00124: val_loss did not improve from 0.00079
# Epoch 125/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.5099e-04 - val_loss: 8.1119e-04
#
# Epoch 00125: val_loss did not improve from 0.00079
# Epoch 126/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.5109e-04 - val_loss: 7.9675e-04
#
# Epoch 00126: val_loss did not improve from 0.00079
# Epoch 127/150
# 27/27 [==============================] - 14s 502ms/step - loss: 1.5087e-04 - val_loss: 8.1827e-04
#
# Epoch 00127: val_loss did not improve from 0.00079
# Epoch 128/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.4970e-04 - val_loss: 8.0962e-04
#
# Epoch 00128: val_loss did not improve from 0.00079
# Epoch 129/150
# 27/27 [==============================] - 14s 501ms/step - loss: 1.5045e-04 - val_loss: 8.0559e-04
#
# Epoch 00129: val_loss did not improve from 0.00079
# Epoch 130/150
# 27/27 [==============================] - 14s 505ms/step - loss: 1.4573e-04 - val_loss: 7.7152e-04
#
# Epoch 00130: val_loss improved from 0.00079 to 0.00077, saving model to best_weights.h5
# Epoch 131/150
# 27/27 [==============================] - 14s 509ms/step - loss: 1.5050e-04 - val_loss: 8.3227e-04
#
# Epoch 00131: val_loss did not improve from 0.00077
# Epoch 132/150
# 27/27 [==============================] - 14s 508ms/step - loss: 1.4719e-04 - val_loss: 8.0290e-04
#
# Epoch 00132: val_loss did not improve from 0.00077
# Epoch 133/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.4467e-04 - val_loss: 7.9057e-04
#
# Epoch 00133: val_loss did not improve from 0.00077
# Epoch 134/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.4152e-04 - val_loss: 7.9325e-04
#
# Epoch 00134: val_loss did not improve from 0.00077
# Epoch 135/150
# 27/27 [==============================] - 14s 502ms/step - loss: 1.4135e-04 - val_loss: 8.0004e-04
#
# Epoch 00135: val_loss did not improve from 0.00077
# Epoch 136/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.3965e-04 - val_loss: 7.9062e-04
#
# Epoch 00136: val_loss did not improve from 0.00077
# Epoch 137/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.3935e-04 - val_loss: 8.1082e-04
#
# Epoch 00137: val_loss did not improve from 0.00077
# Epoch 138/150
# 27/27 [==============================] - 14s 506ms/step - loss: 1.4764e-04 - val_loss: 7.9224e-04
#
# Epoch 00138: val_loss did not improve from 0.00077
# Epoch 139/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.5035e-04 - val_loss: 7.8971e-04
#
# Epoch 00139: val_loss did not improve from 0.00077
# Epoch 140/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.4001e-04 - val_loss: 7.7298e-04
#
# Epoch 00140: val_loss did not improve from 0.00077
# Epoch 141/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.4362e-04 - val_loss: 8.0446e-04
#
# Epoch 00141: val_loss did not improve from 0.00077
# Epoch 142/150
# 27/27 [==============================] - 14s 505ms/step - loss: 1.4329e-04 - val_loss: 8.0811e-04
#
# Epoch 00142: val_loss did not improve from 0.00077
# Epoch 143/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.4155e-04 - val_loss: 8.1676e-04
#
# Epoch 00143: val_loss did not improve from 0.00077
# Epoch 144/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.4464e-04 - val_loss: 8.0309e-04
#
# Epoch 00144: val_loss did not improve from 0.00077
# Epoch 145/150
# 27/27 [==============================] - 14s 505ms/step - loss: 1.4114e-04 - val_loss: 7.8471e-04
#
# Epoch 00145: val_loss did not improve from 0.00077
# Epoch 146/150
# 27/27 [==============================] - 14s 504ms/step - loss: 1.4457e-04 - val_loss: 8.1760e-04
#
# Epoch 00146: val_loss did not improve from 0.00077
# Epoch 147/150
# 27/27 [==============================] - 14s 505ms/step - loss: 1.4143e-04 - val_loss: 8.0089e-04
#
# Epoch 00147: val_loss did not improve from 0.00077
# Epoch 148/150
# 27/27 [==============================] - 14s 503ms/step - loss: 1.3826e-04 - val_loss: 8.5589e-04
#
# Epoch 00148: val_loss did not improve from 0.00077
# Epoch 149/150
# 27/27 [==============================] - 14s 506ms/step - loss: 1.4238e-04 - val_loss: 7.9949e-04
#
# Epoch 00149: val_loss did not improve from 0.00077
# Epoch 150/150
# 27/27 [==============================] - 14s 507ms/step - loss: 1.3874e-04 - val_loss: 7.8892e-04
#
# Epoch 00150: val_loss did not improve from 0.00077

# %%
# loss 值的圖
plt.title('Optimizer : Adam', fontsize=10)
plt.ylabel('Loss', fontsize=16)
plt.plot(hist_model.history['loss'], color='b', label='Training Loss')
plt.plot(hist_model.history['val_loss'], color='r', label='Validation Loss')
plt.legend(loc='upper right')

# %% [markdown]
# ### 觀察 model 在 testing 上的結果

# %%
# 讀取測試資料集
imgs_test, _ = load_data(dirname = 'test.csv')

# %%
# 在灰階圖像上畫關鍵點的函數
def plot_keypoints(img, points):
    plt.imshow(img, cmap='gray')
    for i in range(0,30,2):
        plt.scatter((points[i] + 0.5)*96, (points[i+1]+0.5)*96, color='red')

# %%
fig = plt.figure(figsize=(15,15))
# 在測試集圖片上用剛剛訓練好的模型做關鍵點的預測
points_test = model.predict(imgs_test.reshape(imgs_test.shape[0], 96, 96, 1))

for i in range(16):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    plot_keypoints(imgs_test[i], np.squeeze(points_test[i]))

# %% [markdown]
# 目前為止，大致可以觀察到，直接使用簡單的模型以及訓練方式在這組數據上應該可以在訓練集和測試集上都得到一個還不錯的結果，說明這組資料其實不會很難。

# %%
flip_imgs_train = np.copy(imgs_train[:,:,::-1])
combine_imgs_train = np.concatenate((imgs_train,flip_imgs_train),0)

# %%
flip_point_train = np.copy(points_train)
flip_point_train[0:2],flip_point_train[2:4] = flip_point_train[2:4],flip_point_train[0:2]
flip_point_train[4:6],flip_point_train[6:8],flip_point_train[8:10],flip_point_train[10:12] = flip_point_train[8:10],flip_point_train[10:12],flip_point_train[4:6],flip_point_train[6:8]
flip_point_train[12:14],flip_point_train[16:18],flip_point_train[14:16],flip_point_train[18:20] = flip_point_train[16:18],flip_point_train[12:14],flip_point_train[18:20],flip_point_train[14:16]
flip_point_train[22:24],flip_point_train[24:26] = flip_point_train[24:26],flip_point_train[22:24]

combine_point_train = np.concatenate((points_train,flip_point_train),0)

# %%
model_with_augment = get_model()
model_with_augment.compile(loss='mean_squared_error', optimizer='adam')

checkpoint_augment = ModelCheckpoint('best_weights_flit.h5', verbose=1, save_best_only=True)
aug_hist = History()

flip_model = model_with_augment.fit(combine_imgs_train.reshape(-1,96,96,1),
                                    combine_point_train,
                                    validation_split = 0.2,
                                    batch_size = 64,
                                    callbacks = [checkpoint_augment,aug_hist],
                                    shuffle = True,
                                    epochs = 150,
                                    verbose = 1
                                    )
# Out:
# Epoch 1/150
# 54/54 [==============================] - 29s 503ms/step - loss: 0.0122 - val_loss: 0.0020
#
# Epoch 00001: val_loss improved from inf to 0.00200, saving model to best_weights_flit.h5
# Epoch 2/150
# 54/54 [==============================] - 27s 495ms/step - loss: 0.0021 - val_loss: 0.0016
#
# Epoch 00002: val_loss improved from 0.00200 to 0.00162, saving model to best_weights_flit.h5
# Epoch 3/150
# 54/54 [==============================] - 27s 496ms/step - loss: 0.0016 - val_loss: 0.0015
#
# Epoch 00003: val_loss improved from 0.00162 to 0.00150, saving model to best_weights_flit.h5
# Epoch 4/150
# 54/54 [==============================] - 27s 496ms/step - loss: 0.0014 - val_loss: 0.0015
#
# Epoch 00004: val_loss improved from 0.00150 to 0.00148, saving model to best_weights_flit.h5
# Epoch 5/150
# 54/54 [==============================] - 27s 497ms/step - loss: 0.0013 - val_loss: 0.0014
#
# Epoch 00005: val_loss improved from 0.00148 to 0.00141, saving model to best_weights_flit.h5
# Epoch 6/150
# 54/54 [==============================] - 27s 498ms/step - loss: 0.0011 - val_loss: 0.0014
#
# Epoch 00006: val_loss improved from 0.00141 to 0.00139, saving model to best_weights_flit.h5
# Epoch 7/150
# 54/54 [==============================] - 27s 501ms/step - loss: 9.9555e-04 - val_loss: 0.0015
#
# Epoch 00007: val_loss did not improve from 0.00139
# Epoch 8/150
# 54/54 [==============================] - 27s 499ms/step - loss: 8.9622e-04 - val_loss: 0.0015
#
# Epoch 00008: val_loss did not improve from 0.00139
# Epoch 9/150
# 54/54 [==============================] - 27s 500ms/step - loss: 8.0649e-04 - val_loss: 0.0015
#
# Epoch 00009: val_loss did not improve from 0.00139
# Epoch 10/150
# 54/54 [==============================] - 27s 501ms/step - loss: 7.5869e-04 - val_loss: 0.0016
#
# Epoch 00010: val_loss did not improve from 0.00139
# Epoch 11/150
# 54/54 [==============================] - 27s 500ms/step - loss: 6.9543e-04 - val_loss: 0.0016
#
# Epoch 00011: val_loss did not improve from 0.00139
# Epoch 12/150
# 54/54 [==============================] - 27s 500ms/step - loss: 6.4229e-04 - val_loss: 0.0016
#
# Epoch 00012: val_loss did not improve from 0.00139
# Epoch 13/150
# 54/54 [==============================] - 27s 501ms/step - loss: 6.1063e-04 - val_loss: 0.0017
#
# Epoch 00013: val_loss did not improve from 0.00139
# Epoch 14/150
# 54/54 [==============================] - 27s 499ms/step - loss: 6.0889e-04 - val_loss: 0.0017
#
# Epoch 00014: val_loss did not improve from 0.00139
# Epoch 15/150
# 54/54 [==============================] - 27s 500ms/step - loss: 5.5998e-04 - val_loss: 0.0017
#
# Epoch 00015: val_loss did not improve from 0.00139
# Epoch 16/150
# 54/54 [==============================] - 27s 499ms/step - loss: 5.2014e-04 - val_loss: 0.0017
#
# Epoch 00016: val_loss did not improve from 0.00139
# Epoch 17/150
# 54/54 [==============================] - 27s 500ms/step - loss: 5.1287e-04 - val_loss: 0.0016
#
# Epoch 00017: val_loss did not improve from 0.00139
# Epoch 18/150
# 54/54 [==============================] - 27s 498ms/step - loss: 4.9356e-04 - val_loss: 0.0016
#
# Epoch 00018: val_loss did not improve from 0.00139
# Epoch 19/150
# 54/54 [==============================] - 27s 498ms/step - loss: 4.5671e-04 - val_loss: 0.0018
#
# Epoch 00019: val_loss did not improve from 0.00139
# Epoch 20/150
# 54/54 [==============================] - 27s 497ms/step - loss: 4.5304e-04 - val_loss: 0.0017
#
# Epoch 00020: val_loss did not improve from 0.00139
# Epoch 21/150
# 54/54 [==============================] - 27s 496ms/step - loss: 4.3823e-04 - val_loss: 0.0016
#
# Epoch 00021: val_loss did not improve from 0.00139
# Epoch 22/150
# 54/54 [==============================] - 27s 498ms/step - loss: 4.2796e-04 - val_loss: 0.0017
#
# Epoch 00022: val_loss did not improve from 0.00139
# Epoch 23/150
# 54/54 [==============================] - 27s 501ms/step - loss: 4.1954e-04 - val_loss: 0.0018
#
# Epoch 00023: val_loss did not improve from 0.00139
# Epoch 24/150
# 54/54 [==============================] - 27s 499ms/step - loss: 4.0948e-04 - val_loss: 0.0018
#
# Epoch 00024: val_loss did not improve from 0.00139
# Epoch 25/150
# 54/54 [==============================] - 27s 497ms/step - loss: 3.7636e-04 - val_loss: 0.0018
#
# Epoch 00025: val_loss did not improve from 0.00139
# Epoch 26/150
# 54/54 [==============================] - 27s 498ms/step - loss: 3.8028e-04 - val_loss: 0.0019
#
# Epoch 00026: val_loss did not improve from 0.00139
# Epoch 27/150
# 54/54 [==============================] - 27s 498ms/step - loss: 3.5567e-04 - val_loss: 0.0018
#
# Epoch 00027: val_loss did not improve from 0.00139
# Epoch 28/150
# 54/54 [==============================] - 27s 497ms/step - loss: 3.4875e-04 - val_loss: 0.0017
#
# Epoch 00028: val_loss did not improve from 0.00139
# Epoch 29/150
# 54/54 [==============================] - 27s 496ms/step - loss: 3.5817e-04 - val_loss: 0.0018
#
# Epoch 00029: val_loss did not improve from 0.00139
# Epoch 30/150
# 54/54 [==============================] - 27s 498ms/step - loss: 3.3562e-04 - val_loss: 0.0018
#
# Epoch 00030: val_loss did not improve from 0.00139
# Epoch 31/150
# 54/54 [==============================] - 27s 496ms/step - loss: 3.3270e-04 - val_loss: 0.0019
#
# Epoch 00031: val_loss did not improve from 0.00139
# Epoch 32/150
# 54/54 [==============================] - 27s 499ms/step - loss: 3.2012e-04 - val_loss: 0.0019
#
# Epoch 00032: val_loss did not improve from 0.00139
# Epoch 33/150
# 54/54 [==============================] - 27s 497ms/step - loss: 3.0981e-04 - val_loss: 0.0019
#
# Epoch 00033: val_loss did not improve from 0.00139
# Epoch 34/150
# 54/54 [==============================] - 27s 497ms/step - loss: 3.1067e-04 - val_loss: 0.0019
#
# Epoch 00034: val_loss did not improve from 0.00139
# Epoch 35/150
# 54/54 [==============================] - 27s 499ms/step - loss: 3.0004e-04 - val_loss: 0.0019
#
# Epoch 00035: val_loss did not improve from 0.00139
# Epoch 36/150
# 54/54 [==============================] - 27s 498ms/step - loss: 2.9944e-04 - val_loss: 0.0019
#
# Epoch 00036: val_loss did not improve from 0.00139
# Epoch 37/150
# 54/54 [==============================] - 27s 498ms/step - loss: 2.8930e-04 - val_loss: 0.0019
#
# Epoch 00037: val_loss did not improve from 0.00139
# Epoch 38/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.9382e-04 - val_loss: 0.0019
#
# Epoch 00038: val_loss did not improve from 0.00139
# Epoch 39/150
# 54/54 [==============================] - 27s 498ms/step - loss: 2.7797e-04 - val_loss: 0.0019
#
# Epoch 00039: val_loss did not improve from 0.00139
# Epoch 40/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.7806e-04 - val_loss: 0.0018
#
# Epoch 00040: val_loss did not improve from 0.00139
# Epoch 41/150
# 54/54 [==============================] - 27s 496ms/step - loss: 2.6634e-04 - val_loss: 0.0018
#
# Epoch 00041: val_loss did not improve from 0.00139
# Epoch 42/150
# 54/54 [==============================] - 27s 498ms/step - loss: 2.6121e-04 - val_loss: 0.0019
#
# Epoch 00042: val_loss did not improve from 0.00139
# Epoch 43/150
# 54/54 [==============================] - 27s 498ms/step - loss: 2.6760e-04 - val_loss: 0.0019
#
# Epoch 00043: val_loss did not improve from 0.00139
# Epoch 44/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.5213e-04 - val_loss: 0.0019
#
# Epoch 00044: val_loss did not improve from 0.00139
# Epoch 45/150
# 54/54 [==============================] - 27s 496ms/step - loss: 2.5272e-04 - val_loss: 0.0019
#
# Epoch 00045: val_loss did not improve from 0.00139
# Epoch 46/150
# 54/54 [==============================] - 27s 498ms/step - loss: 2.5299e-04 - val_loss: 0.0019
#
# Epoch 00046: val_loss did not improve from 0.00139
# Epoch 47/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.4575e-04 - val_loss: 0.0020
#
# Epoch 00047: val_loss did not improve from 0.00139
# Epoch 48/150
# 54/54 [==============================] - 27s 498ms/step - loss: 2.4558e-04 - val_loss: 0.0019
#
# Epoch 00048: val_loss did not improve from 0.00139
# Epoch 49/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.4009e-04 - val_loss: 0.0019
#
# Epoch 00049: val_loss did not improve from 0.00139
# Epoch 50/150
# 54/54 [==============================] - 27s 500ms/step - loss: 2.3978e-04 - val_loss: 0.0019
#
# Epoch 00050: val_loss did not improve from 0.00139
# Epoch 51/150
# 54/54 [==============================] - 27s 499ms/step - loss: 2.3530e-04 - val_loss: 0.0019
#
# Epoch 00051: val_loss did not improve from 0.00139
# Epoch 52/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.4144e-04 - val_loss: 0.0020
#
# Epoch 00052: val_loss did not improve from 0.00139
# Epoch 53/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.3906e-04 - val_loss: 0.0019
#
# Epoch 00053: val_loss did not improve from 0.00139
# Epoch 54/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.3220e-04 - val_loss: 0.0020
#
# Epoch 00054: val_loss did not improve from 0.00139
# Epoch 55/150
# 54/54 [==============================] - 27s 498ms/step - loss: 2.2362e-04 - val_loss: 0.0020
#
# Epoch 00055: val_loss did not improve from 0.00139
# Epoch 56/150
# 54/54 [==============================] - 27s 496ms/step - loss: 2.2478e-04 - val_loss: 0.0019
#
# Epoch 00056: val_loss did not improve from 0.00139
# Epoch 57/150
# 54/54 [==============================] - 27s 498ms/step - loss: 2.2287e-04 - val_loss: 0.0019
#
# Epoch 00057: val_loss did not improve from 0.00139
# Epoch 58/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.2078e-04 - val_loss: 0.0019
#
# Epoch 00058: val_loss did not improve from 0.00139
# Epoch 59/150
# 54/54 [==============================] - 27s 498ms/step - loss: 2.2021e-04 - val_loss: 0.0019
#
# Epoch 00059: val_loss did not improve from 0.00139
# Epoch 60/150
# 54/54 [==============================] - 27s 496ms/step - loss: 2.1648e-04 - val_loss: 0.0020
#
# Epoch 00060: val_loss did not improve from 0.00139
# Epoch 61/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.1563e-04 - val_loss: 0.0019
#
# Epoch 00061: val_loss did not improve from 0.00139
# Epoch 62/150
# 54/54 [==============================] - 27s 498ms/step - loss: 2.1454e-04 - val_loss: 0.0019
#
# Epoch 00062: val_loss did not improve from 0.00139
# Epoch 63/150
# 54/54 [==============================] - 27s 496ms/step - loss: 2.1681e-04 - val_loss: 0.0019
#
# Epoch 00063: val_loss did not improve from 0.00139
# Epoch 64/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.1119e-04 - val_loss: 0.0019
#
# Epoch 00064: val_loss did not improve from 0.00139
# Epoch 65/150
# 54/54 [==============================] - 27s 496ms/step - loss: 2.0744e-04 - val_loss: 0.0019
#
# Epoch 00065: val_loss did not improve from 0.00139
# Epoch 66/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.0298e-04 - val_loss: 0.0019
#
# Epoch 00066: val_loss did not improve from 0.00139
# Epoch 67/150
# 54/54 [==============================] - 27s 496ms/step - loss: 2.0377e-04 - val_loss: 0.0019
#
# Epoch 00067: val_loss did not improve from 0.00139
# Epoch 68/150
# 54/54 [==============================] - 27s 495ms/step - loss: 2.0963e-04 - val_loss: 0.0019
#
# Epoch 00068: val_loss did not improve from 0.00139
# Epoch 69/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.0706e-04 - val_loss: 0.0019
#
# Epoch 00069: val_loss did not improve from 0.00139
# Epoch 70/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.0190e-04 - val_loss: 0.0020
#
# Epoch 00070: val_loss did not improve from 0.00139
# Epoch 71/150
# 54/54 [==============================] - 27s 498ms/step - loss: 2.0348e-04 - val_loss: 0.0019
#
# Epoch 00071: val_loss did not improve from 0.00139
# Epoch 72/150
# 54/54 [==============================] - 27s 497ms/step - loss: 2.0231e-04 - val_loss: 0.0019
#
# Epoch 00072: val_loss did not improve from 0.00139
# Epoch 73/150
# 54/54 [==============================] - 27s 496ms/step - loss: 2.0411e-04 - val_loss: 0.0019
#
# Epoch 00073: val_loss did not improve from 0.00139
# Epoch 74/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.9625e-04 - val_loss: 0.0019
#
# Epoch 00074: val_loss did not improve from 0.00139
# Epoch 75/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.9921e-04 - val_loss: 0.0019
#
# Epoch 00075: val_loss did not improve from 0.00139
# Epoch 76/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.9647e-04 - val_loss: 0.0019
#
# Epoch 00076: val_loss did not improve from 0.00139
# Epoch 77/150
# 54/54 [==============================] - 27s 495ms/step - loss: 2.0079e-04 - val_loss: 0.0019
#
# Epoch 00077: val_loss did not improve from 0.00139
# Epoch 78/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.8923e-04 - val_loss: 0.0020
#
# Epoch 00078: val_loss did not improve from 0.00139
# Epoch 79/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.8863e-04 - val_loss: 0.0019
#
# Epoch 00079: val_loss did not improve from 0.00139
# Epoch 80/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.9405e-04 - val_loss: 0.0020
#
# Epoch 00080: val_loss did not improve from 0.00139
# Epoch 81/150
# 54/54 [==============================] - 27s 499ms/step - loss: 1.9088e-04 - val_loss: 0.0019
#
# Epoch 00081: val_loss did not improve from 0.00139
# Epoch 82/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.8512e-04 - val_loss: 0.0019
#
# Epoch 00082: val_loss did not improve from 0.00139
# Epoch 83/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.8731e-04 - val_loss: 0.0019
#
# Epoch 00083: val_loss did not improve from 0.00139
# Epoch 84/150
# 54/54 [==============================] - 27s 499ms/step - loss: 1.8437e-04 - val_loss: 0.0019
#
# Epoch 00084: val_loss did not improve from 0.00139
# Epoch 85/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.8934e-04 - val_loss: 0.0019
#
# Epoch 00085: val_loss did not improve from 0.00139
# Epoch 86/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.8404e-04 - val_loss: 0.0019
#
# Epoch 00086: val_loss did not improve from 0.00139
# Epoch 87/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.8054e-04 - val_loss: 0.0019
#
# Epoch 00087: val_loss did not improve from 0.00139
# Epoch 88/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.8882e-04 - val_loss: 0.0019
#
# Epoch 00088: val_loss did not improve from 0.00139
# Epoch 89/150
# 54/54 [==============================] - 27s 509ms/step - loss: 1.8133e-04 - val_loss: 0.0018
#
# Epoch 00089: val_loss did not improve from 0.00139
# Epoch 90/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.8245e-04 - val_loss: 0.0019
#
# Epoch 00090: val_loss did not improve from 0.00139
# Epoch 91/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.8415e-04 - val_loss: 0.0018
#
# Epoch 00091: val_loss did not improve from 0.00139
# Epoch 92/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.7859e-04 - val_loss: 0.0019
#
# Epoch 00092: val_loss did not improve from 0.00139
# Epoch 93/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.8263e-04 - val_loss: 0.0020
#
# Epoch 00093: val_loss did not improve from 0.00139
# Epoch 94/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.7792e-04 - val_loss: 0.0018
#
# Epoch 00094: val_loss did not improve from 0.00139
# Epoch 95/150
# 54/54 [==============================] - 27s 495ms/step - loss: 1.8319e-04 - val_loss: 0.0019
#
# Epoch 00095: val_loss did not improve from 0.00139
# Epoch 96/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.8184e-04 - val_loss: 0.0019
#
# Epoch 00096: val_loss did not improve from 0.00139
# Epoch 97/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.8004e-04 - val_loss: 0.0019
#
# Epoch 00097: val_loss did not improve from 0.00139
# Epoch 98/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.7487e-04 - val_loss: 0.0018
#
# Epoch 00098: val_loss did not improve from 0.00139
# Epoch 99/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.7657e-04 - val_loss: 0.0018
#
# Epoch 00099: val_loss did not improve from 0.00139
# Epoch 100/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.7529e-04 - val_loss: 0.0019
#
# Epoch 00100: val_loss did not improve from 0.00139
# Epoch 101/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.7404e-04 - val_loss: 0.0019
#
# Epoch 00101: val_loss did not improve from 0.00139
# Epoch 102/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.7881e-04 - val_loss: 0.0019
#
# Epoch 00102: val_loss did not improve from 0.00139
# Epoch 103/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.7471e-04 - val_loss: 0.0019
#
# Epoch 00103: val_loss did not improve from 0.00139
# Epoch 104/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.6820e-04 - val_loss: 0.0019
#
# Epoch 00104: val_loss did not improve from 0.00139
# Epoch 105/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.7079e-04 - val_loss: 0.0020
#
# Epoch 00105: val_loss did not improve from 0.00139
# Epoch 106/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.6866e-04 - val_loss: 0.0018
#
# Epoch 00106: val_loss did not improve from 0.00139
# Epoch 107/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.7019e-04 - val_loss: 0.0019
#
# Epoch 00107: val_loss did not improve from 0.00139
# Epoch 108/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.7078e-04 - val_loss: 0.0019
#
# Epoch 00108: val_loss did not improve from 0.00139
# Epoch 109/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.6528e-04 - val_loss: 0.0019
#
# Epoch 00109: val_loss did not improve from 0.00139
# Epoch 110/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.6511e-04 - val_loss: 0.0019
#
# Epoch 00110: val_loss did not improve from 0.00139
# Epoch 111/150
# 54/54 [==============================] - 27s 499ms/step - loss: 1.7255e-04 - val_loss: 0.0018
#
# Epoch 00111: val_loss did not improve from 0.00139
# Epoch 112/150
# 54/54 [==============================] - 27s 495ms/step - loss: 1.6293e-04 - val_loss: 0.0018
#
# Epoch 00112: val_loss did not improve from 0.00139
# Epoch 113/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.6624e-04 - val_loss: 0.0019
#
# Epoch 00113: val_loss did not improve from 0.00139
# Epoch 114/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.6656e-04 - val_loss: 0.0019
#
# Epoch 00114: val_loss did not improve from 0.00139
# Epoch 115/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.6743e-04 - val_loss: 0.0018
#
# Epoch 00115: val_loss did not improve from 0.00139
# Epoch 116/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.7122e-04 - val_loss: 0.0018
#
# Epoch 00116: val_loss did not improve from 0.00139
# Epoch 117/150
# 54/54 [==============================] - 27s 499ms/step - loss: 1.6105e-04 - val_loss: 0.0018
#
# Epoch 00117: val_loss did not improve from 0.00139
# Epoch 118/150
# 54/54 [==============================] - 27s 502ms/step - loss: 1.7196e-04 - val_loss: 0.0019
#
# Epoch 00118: val_loss did not improve from 0.00139
# Epoch 119/150
# 54/54 [==============================] - 27s 500ms/step - loss: 1.6274e-04 - val_loss: 0.0019
#
# Epoch 00119: val_loss did not improve from 0.00139
# Epoch 120/150
# 54/54 [==============================] - 27s 501ms/step - loss: 1.5759e-04 - val_loss: 0.0018
#
# Epoch 00120: val_loss did not improve from 0.00139
# Epoch 121/150
# 54/54 [==============================] - 27s 499ms/step - loss: 1.6635e-04 - val_loss: 0.0018
#
# Epoch 00121: val_loss did not improve from 0.00139
# Epoch 122/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.6346e-04 - val_loss: 0.0019
#
# Epoch 00122: val_loss did not improve from 0.00139
# Epoch 123/150
# 54/54 [==============================] - 27s 500ms/step - loss: 1.6274e-04 - val_loss: 0.0018
#
# Epoch 00123: val_loss did not improve from 0.00139
# Epoch 124/150
# 54/54 [==============================] - 27s 499ms/step - loss: 1.6508e-04 - val_loss: 0.0019
#
# Epoch 00124: val_loss did not improve from 0.00139
# Epoch 125/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.5910e-04 - val_loss: 0.0019
#
# Epoch 00125: val_loss did not improve from 0.00139
# Epoch 126/150
# 54/54 [==============================] - 27s 499ms/step - loss: 1.5618e-04 - val_loss: 0.0019
#
# Epoch 00126: val_loss did not improve from 0.00139
# Epoch 127/150
# 54/54 [==============================] - 27s 501ms/step - loss: 1.6348e-04 - val_loss: 0.0019
#
# Epoch 00127: val_loss did not improve from 0.00139
# Epoch 128/150
# 54/54 [==============================] - 27s 499ms/step - loss: 1.6215e-04 - val_loss: 0.0019
#
# Epoch 00128: val_loss did not improve from 0.00139
# Epoch 129/150
# 54/54 [==============================] - 27s 499ms/step - loss: 1.5634e-04 - val_loss: 0.0019
#
# Epoch 00129: val_loss did not improve from 0.00139
# Epoch 130/150
# 54/54 [==============================] - 27s 500ms/step - loss: 1.5895e-04 - val_loss: 0.0019
#
# Epoch 00130: val_loss did not improve from 0.00139
# Epoch 131/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.5554e-04 - val_loss: 0.0019
#
# Epoch 00131: val_loss did not improve from 0.00139
# Epoch 132/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.5695e-04 - val_loss: 0.0018
#
# Epoch 00132: val_loss did not improve from 0.00139
# Epoch 133/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.6271e-04 - val_loss: 0.0019
#
# Epoch 00133: val_loss did not improve from 0.00139
# Epoch 134/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.5149e-04 - val_loss: 0.0019
#
# Epoch 00134: val_loss did not improve from 0.00139
# Epoch 135/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.5712e-04 - val_loss: 0.0018
#
# Epoch 00135: val_loss did not improve from 0.00139
# Epoch 136/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.5229e-04 - val_loss: 0.0019
#
# Epoch 00136: val_loss did not improve from 0.00139
# Epoch 137/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.5555e-04 - val_loss: 0.0018
#
# Epoch 00137: val_loss did not improve from 0.00139
# Epoch 138/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.5827e-04 - val_loss: 0.0018
#
# Epoch 00138: val_loss did not improve from 0.00139
# Epoch 139/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.5836e-04 - val_loss: 0.0019
#
# Epoch 00139: val_loss did not improve from 0.00139
# Epoch 140/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.5702e-04 - val_loss: 0.0018
#
# Epoch 00140: val_loss did not improve from 0.00139
# Epoch 141/150
# 54/54 [==============================] - 27s 500ms/step - loss: 1.5460e-04 - val_loss: 0.0018
#
# Epoch 00141: val_loss did not improve from 0.00139
# Epoch 142/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.6090e-04 - val_loss: 0.0019
#
# Epoch 00142: val_loss did not improve from 0.00139
# Epoch 143/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.5945e-04 - val_loss: 0.0018
#
# Epoch 00143: val_loss did not improve from 0.00139
# Epoch 144/150
# 54/54 [==============================] - 27s 499ms/step - loss: 1.5273e-04 - val_loss: 0.0018
#
# Epoch 00144: val_loss did not improve from 0.00139
# Epoch 145/150
# 54/54 [==============================] - 27s 498ms/step - loss: 1.5222e-04 - val_loss: 0.0019
#
# Epoch 00145: val_loss did not improve from 0.00139
# Epoch 146/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.5124e-04 - val_loss: 0.0019
#
# Epoch 00146: val_loss did not improve from 0.00139
# Epoch 147/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.5389e-04 - val_loss: 0.0018
#
# Epoch 00147: val_loss did not improve from 0.00139
# Epoch 148/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.5072e-04 - val_loss: 0.0017
#
# Epoch 00148: val_loss did not improve from 0.00139
# Epoch 149/150
# 54/54 [==============================] - 27s 496ms/step - loss: 1.4927e-04 - val_loss: 0.0019
#
# Epoch 00149: val_loss did not improve from 0.00139
# Epoch 150/150
# 54/54 [==============================] - 27s 497ms/step - loss: 1.4733e-04 - val_loss: 0.0018
#
# Epoch 00150: val_loss did not improve from 0.00139

# %%
import pandas as pd 
pd.DataFrame(flip_model.history).plot()
